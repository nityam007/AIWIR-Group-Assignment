# %% [markdown]
# <a href="https://colab.research.google.com/github/nityam007/AIWIR-Group-Assignment/blob/main/Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
import re 
nlp = spacy.load("en_core_web_sm")
doc = nlp("Atp. Bhalwani Tal. Mangalwedha Dist. Solapur https://helloWorld.com")
copy = "Atp. Bhalwani Tal. Mangalwedha Dist. Solapur https://helloWorld.com"
print(re.search("(?P<url>https?://[^\s]+)", copy).group("url"))
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
ent[0]
# Out:
# https://helloWorld.com
# Bhalwani Tal 5 17 PERSON
# Mangalwedha Dist 19 35 PERSON
# Solapur 37 44 GPE
# Solapur

# %%
pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Atp. Bhalwani Tal. Mangalwedha Dist. Solapur")
for ent in doc.ents:
    if ent.label == 384:
      print(ent.text)
      #print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Solapur

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Aspiratations, Needs & Business Interest (Responses) - Form Responses 1.csv")

# %%
data.head()
# Out:
#             Timestamp  Unnamed: 1                       Name  Unnamed: 3  \
# 0  4/12/2021 12:09:34         NaN                     Deepak         NaN
# 1  4/12/2021 12:30:37         NaN     Pooja Babruvahan Ronge         NaN
# 2  4/12/2021 13:03:47         NaN         Shantanu Uday Jade         NaN
# 3  4/12/2021 13:13:26         NaN  Prathamesh Prashant Patil         NaN
# 4  4/12/2021 13:13:32         NaN     Pramod Tanaji Awalekar         NaN
#
#              Year  Department Date of Birth  \
# 0              II       Civil    10/20/1989
# 1  Not Applicable       Civil     3/17/1998
# 2              II  Mechanical      8/3/2001
# 3              II  Mechanical     8/22/2001
# 4              II  Mechanical     10/1/2001
#
#                                Permanent Address  \
# 0                                         adsfad
# 1                     Golden Colony, Pandharpur.
# 2           Solapur Masre Galli Moreshwar apt \n
# 3  AP- Bramhapuri,Teh- Mangalwedha, Dist-Solapur
# ...

# %%
data_columns = data['Permanent Address']
data_columns
# Out:
# 0                                                 adsfad
# 1                             Golden Colony, Pandharpur.
# 2                   Solapur Masre Galli Moreshwar apt \n
# 3          AP- Bramhapuri,Teh- Mangalwedha, Dist-Solapur
# 4           Atp. Bhalwani Tal. Mangalwedha Dist. Solapur
#                              ...
# 447    Near vital mandir, shaneshwar galli, kurduwadi...
# 448                     Uplai road, Waykule plot, Barshi
# 449                               Juni Peth , Pandharpur
# 450                    At.post.Salgar BK Tal-Mangalwedha
# 451                Bhai Bhai chouk  Santhpeth Pandharpur
# Name: Permanent Address, Length: 452, dtype: object

# %%
c = []
for a in data_columns:
  doc = nlp(a)
  for ent in doc.ents:
    if ent.label == 384:
      c.append(ent.text.upper())
      #print(ent.text, ent.start_char, ent.end_char, ent.label_)
len(c)
# Out:
# 114

# %%
data["Department"].value_counts()
# Out:
# CSE           151
# EnTC           87
# MBA            62
# Mechanical     52
# Electrical     52
# Civil          48
# Name: Department, dtype: int64

# %%
cleanup_nums = {"Department":     {"CSE": 1, "EnTC": 2,"MBA":3,"Mechanical":4,"Electrical":5,"Civil":6}}

# %%
cleanup_nums
# Out:
# {'Department': {'CSE': 1,
#   'Civil': 6,
#   'Electrical': 5,
#   'EnTC': 2,
#   'MBA': 3,
#   'Mechanical': 4}}

# %%
copy_df = data.replace(cleanup_nums)
copy_df.head()
# Out:
#             Timestamp  Unnamed: 1                       Name  Unnamed: 3  \
# 0  4/12/2021 12:09:34         NaN                     Deepak         NaN
# 1  4/12/2021 12:30:37         NaN     Pooja Babruvahan Ronge         NaN
# 2  4/12/2021 13:03:47         NaN         Shantanu Uday Jade         NaN
# 3  4/12/2021 13:13:26         NaN  Prathamesh Prashant Patil         NaN
# 4  4/12/2021 13:13:32         NaN     Pramod Tanaji Awalekar         NaN
#
#              Year  Department Date of Birth  \
# 0              II           6    10/20/1989
# 1  Not Applicable           6     3/17/1998
# 2              II           4      8/3/2001
# 3              II           4     8/22/2001
# 4              II           4     10/1/2001
#
#                                Permanent Address  \
# 0                                         adsfad
# 1                     Golden Colony, Pandharpur.
# 2           Solapur Masre Galli Moreshwar apt \n
# 3  AP- Bramhapuri,Teh- Mangalwedha, Dist-Solapur
# ...

# %%
for a in data_columns:
  doc = nlp(a)
  for ent in doc.ents:
    #if ent.label == 384:
    b = ent.text
    data["Permanent Address"] = data["Permanent Address"].replace(b)
data.head(50)
# Out:
#              Timestamp  Unnamed: 1                           Name  Unnamed: 3  \
# 0   4/12/2021 12:09:34         NaN                         Deepak         NaN
# 1   4/12/2021 12:30:37         NaN         Pooja Babruvahan Ronge         NaN
# 2   4/12/2021 13:03:47         NaN             Shantanu Uday Jade         NaN
# 3   4/12/2021 13:13:26         NaN      Prathamesh Prashant Patil         NaN
# 4   4/12/2021 13:13:32         NaN         Pramod Tanaji Awalekar         NaN
# 5   4/12/2021 13:13:55         NaN                  Rahul khadake         NaN
# 6   4/12/2021 13:21:02         NaN    Rajkumar Bhimasha Yalasangi         NaN
# 7   4/12/2021 13:21:35         NaN         Ajit Suryakant Gaikwad         NaN
# 8   4/12/2021 13:37:58         NaN                   Suhas Nashte         NaN
# 9   4/12/2021 13:52:29         NaN       Khandalkar Gaurav Sunil          NaN
# 10  4/12/2021 14:09:50         NaN          Nikhil Rajkumar Pawar         NaN
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(c[:10])
plt.show()

# %%
data
data.value_counts()
# Out:
# Series([], dtype: int64)

# %%
data.head()
# Out:
#             Timestamp  Unnamed: 1                       Name  Unnamed: 3  \
# 0  4/12/2021 12:09:34         NaN                     Deepak         NaN
# 1  4/12/2021 12:30:37         NaN     Pooja Babruvahan Ronge         NaN
# 2  4/12/2021 13:03:47         NaN         Shantanu Uday Jade         NaN
# 3  4/12/2021 13:13:26         NaN  Prathamesh Prashant Patil         NaN
# 4  4/12/2021 13:13:32         NaN     Pramod Tanaji Awalekar         NaN
#
#              Year  Department Date of Birth  \
# 0              II       Civil    10/20/1989
# 1  Not Applicable       Civil     3/17/1998
# 2              II  Mechanical      8/3/2001
# 3              II  Mechanical     8/22/2001
# 4              II  Mechanical     10/1/2001
#
#                                Permanent Address  \
# 0                                         adsfad
# 1                     Golden Colony, Pandharpur.
# 2           Solapur Masre Galli Moreshwar apt \n
# 3  AP- Bramhapuri,Teh- Mangalwedha, Dist-Solapur
# ...

# %%
data
# Out:
#               Timestamp  Unnamed: 1                        Name  Unnamed: 3  \
# 0    4/12/2021 12:09:34         NaN                      Deepak         NaN
# 1    4/12/2021 12:30:37         NaN      Pooja Babruvahan Ronge         NaN
# 2    4/12/2021 13:03:47         NaN          Shantanu Uday Jade         NaN
# 3    4/12/2021 13:13:26         NaN   Prathamesh Prashant Patil         NaN
# 4    4/12/2021 13:13:32         NaN      Pramod Tanaji Awalekar         NaN
# ..                  ...         ...                         ...         ...
# 447  4/27/2021 17:48:36         NaN              Sidhali narute         NaN
# 448  4/27/2021 19:16:34         NaN  Sumedh Sanjaykumar Gaikwad         NaN
# 449  4/27/2021 20:44:45         NaN              Saleha Mirjkar         NaN
# 450  4/28/2021 12:15:21         NaN   Aishwarya Waman Kulkarni          NaN
# 451  4/28/2021 17:13:47         NaN      Shivkumar Sunil Gosavi         NaN
#
#                Year  Department Date of Birth  \
# ...

# %%
data1 = pd.read_csv("/content/Copy of Open House on IGNITE and ACTIVATE Programs (Responses) - Form Responses 1.csv")

# %%
data1.head()
# Out:
#             Timestamp                   Name  Unnamed: 2  Unnamed: 3      Age  \
# 0  8/27/2021 21:53:53         Akanksha Sinha         NaN         NaN  Ancient
# 1  8/28/2021 11:36:55  Prof Sathya Praveen D         NaN         NaN       35
# 2  8/28/2021 12:22:45          Ashish Tiwari         NaN         NaN       43
# 3  8/28/2021 17:28:08       Amitkumar Shelar         NaN         NaN       32
# 4  8/29/2021 17:21:18              Kavana BS         NaN         NaN       40
#
#               Gender Are you a  \
# 0  Prefer not to say    Others
# 1               Male   Faculty
# 2               Male   Faculty
# 3               Male   Faculty
# 4             Female     Other
#
#            Name of the Academic Institute/Enterprise  \
# 0                              The Institute of Life
# 1  CSMSS Chh Shahu College of Engineering, Aurang...
# 2             A R Kalsekar Polytechnic, Navi Mumbai.
# 3  SVPM's Institute of Technology and Engineering...
# ...

# %%
obj_df["OHC_Code"] = np.where(obj_df["engine_type"].str.contains("ohc"), 1, 0)

# %%
cleanup_nums = {"Gender":     {"CSE": 1, "EnTC": 2,"MBA":3,"Mechanical":4,"Electrical":5,"Civil":6}}
